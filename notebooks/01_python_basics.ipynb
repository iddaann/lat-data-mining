# %%
print("hello data science")
# Out:
# hello data science

# %%
import pandas as pd

print("hello panda, dan panda berhasil di import")
# Out:
# hello panda, dan panda berhasil di import

# %%
import pandas as pd

df = pd.read_csv("../students.csv")

# %%
df
# Out:
#     nama  umur           jurusan  kehadiran  tugas  uts  uas  ipk
# 0   Andi    20       Informatika         90     85   80   88  3.5
# 1   Budi    21       Informatika         75     70   65   72  2.8
# 2  Citra    20  Sistem Informasi         95     90   88   92  3.8
# 3   Deni    22       Informatika         60     65   55   60  2.3
# 4    Eka    21  Sistem Informasi         88     82   78   85  3.4
# 5  Fajar    20       Informatika         92     88   85   90  3.7
# 6   Gina    22  Sistem Informasi         70     75   68   70  2.7
# 7   Hadi    21       Informatika         85     80   75   82  3.2
# 8  Indah    20  Sistem Informasi         98     95   92   96  3.9
# 9   Joko    23       Informatika         65     60   58   62  2.4

# %%
df.head()
# Out:
#     nama  umur           jurusan  kehadiran  tugas  uts  uas  ipk
# 0   Andi    20       Informatika         90     85   80   88  3.5
# 1   Budi    21       Informatika         75     70   65   72  2.8
# 2  Citra    20  Sistem Informasi         95     90   88   92  3.8
# 3   Deni    22       Informatika         60     65   55   60  2.3
# 4    Eka    21  Sistem Informasi         88     82   78   85  3.4

# %%
df.tail()
# Out:
#     nama  umur           jurusan  kehadiran  tugas  uts  uas  ipk
# 5  Fajar    20       Informatika         92     88   85   90  3.7
# 6   Gina    22  Sistem Informasi         70     75   68   70  2.7
# 7   Hadi    21       Informatika         85     80   75   82  3.2
# 8  Indah    20  Sistem Informasi         98     95   92   96  3.9
# 9   Joko    23       Informatika         65     60   58   62  2.4

# %%
df.shape
# Out:
# (10, 8)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   nama       10 non-null     str
#  1   umur       10 non-null     int64
#  2   jurusan    10 non-null     str
#  3   kehadiran  10 non-null     int64
#  4   tugas      10 non-null     int64
#  5   uts        10 non-null     int64
#  6   uas        10 non-null     int64
#  7   ipk        10 non-null     float64
# dtypes: float64(1), int64(5), str(2)
# memory usage: 772.0 bytes

# %%
print(df.ftypes))
# Out:
#   Cell In[10], line 1
#     print(df.ftypes))
#                     ^
# SyntaxError: unmatched ')'

# %%
print(df.dtypes)
# Out:
# nama             str
# umur           int64
# jurusan          str
# kehadiran      int64
# tugas          int64
# uts            int64
# uas            int64
# ipk          float64
# dtype: object

# %%
df.describe()
# Out:
#             umur  kehadiran      tugas        uts        uas        ipk
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   21.000000  81.800000  79.000000  74.400000  79.700000   3.170000
# std     1.054093  13.331667  11.343133  12.589237  12.824023   0.585093
# min    20.000000  60.000000  60.000000  55.000000  60.000000   2.300000
# 25%    20.000000  71.250000  71.250000  65.750000  70.500000   2.725000
# 50%    21.000000  86.500000  81.000000  76.500000  83.500000   3.300000
# 75%    21.750000  91.500000  87.250000  83.750000  89.500000   3.650000
# max    23.000000  98.000000  95.000000  92.000000  96.000000   3.900000

# %%
df.corr(numeric_only=True)
# Out:
#                umur  kehadiran     tugas       uts       uas       ipk
# umur       1.000000  -0.909268 -0.910693 -0.887534 -0.920603 -0.918807
# kehadiran -0.909268   1.000000  0.955176  0.980325  0.996562  0.993414
# tugas     -0.910693   0.955176  1.000000  0.984273  0.975419  0.972693
# uts       -0.887534   0.980325  0.984273  1.000000  0.989125  0.991359
# uas       -0.920603   0.996562  0.975419  0.989125  1.000000  0.996755
# ipk       -0.918807   0.993414  0.972693  0.991359  0.996755  1.000000

# %%
df.describe().sum()
# Out:
# umur         137.804093
# kehadiran    512.381667
# tugas        494.843133
# uts          469.989237
# uas          502.024023
# ipk           29.630093
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[(df['kehadiran'] > 100) | (df['ipk'] > 4.0)]
# Out:
# Empty DataFrame
# Columns: [nama, umur, jurusan, kehadiran, tugas, uts, uas, ipk]
# Index: []

# %%
df['status'] = df['ipk'].apply(lambda x: 'lulus' if x >= 3.0 else 'tidak lulus')

# %%
df[['nama', 'ipk', 'status']]
# Out:
#     nama  ipk       status
# 0   Andi  3.5        lulus
# 1   Budi  2.8  tidak lulus
# 2  Citra  3.8        lulus
# 3   Deni  2.3  tidak lulus
# 4    Eka  3.4        lulus
# 5  Fajar  3.7        lulus
# 6   Gina  2.7  tidak lulus
# 7   Hadi  3.2        lulus
# 8  Indah  3.9        lulus
# 9   Joko  2.4  tidak lulus

# %%
groupby()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 groupby()
#
# NameError: name 'groupby' is not defined

# %%
df.groupby('jurusan')['ipk'].mean()
# Out:
# jurusan
# Informatika         2.983333
# Sistem Informasi    3.450000
# Name: ipk, dtype: float64

# %%
df.groupby('jurusan')['ipk'].agg(['mean', 'min', 'max', 'count'])
# Out:
#                       mean  min  max  count
# jurusan
# Informatika       2.983333  2.3  3.7      6
# Sistem Informasi  3.450000  2.7  3.9      4

# %%
df.groupby('status')[['kehadiran', 'tugas', 'uts', 'uas',]].mean()
# Out:
#              kehadiran      tugas   uts        uas
# status
# lulus        91.333333  86.666667  83.0  88.833333
# tidak lulus  67.500000  67.500000  61.5  66.000000

# %%
import matplotlib.pyplot as plt

plt.scatter(df['kehadiran'], df['ipk'])
plt.title('Hubungan Kehadiran vs IPK')
plt.xlabel('Kehadiran (%)')
plt.ylabel('IPK')
plt.show()

# %%
df.boxplot(column=['ipk', 'tugas', 'uts', 'uas'])
plt.title('boxplot komponen nilai')
plt.show()

# %%
x = df[['kehadiran','tugas','uts','uas']]
y = df['status']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
print(x_train.shape, x_test.shape)
# Out:
# (8, 4) (2, 4)

# %%
x = df[['kehadiran', 'tugas', 'uts', 'uas']]
y = df['status']

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, x_test = train_test_split(x, y, test_size=0.2, random_state=42)

print(x_train.shape, x_test.shape)
# Out:
# (8, 4) (2,)

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(random_state=42)
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = model.predict(x_test)
print(y_pred)
print(y_test)
# Out:
# d:\ai-web-scrapper\.env\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 y_pred = model.predict(x_test)
#       2 print(y_pred)
#       3 print(y_test)
#
# File d:\ai-web-scrapper\.env\Lib\site-packages\sklearn\tree\_classes.py:525, in BaseDecisionTree.predict(self, X, check_input)
#     502 """Predict class or regression value for X.
#     503
#     504 For a classification model, the predicted class for each sample in X is
#    (...)    522     The predicted classes, or the predict values.
#     523 """
#     524 check_is_fitted(self)
# --> 525 X = self._validate_X_predict(X, check_input)
#     526 proba = self.tree_.predict(X)
#     527 n_samples = X.shape[0]
#
# ...
